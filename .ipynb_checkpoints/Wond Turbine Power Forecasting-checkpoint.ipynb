# %% [markdown]
# # Turbine Power Data
#
# Using the data provided in the csv file the task is to predict power output for the next 15 days.
#
# Several methods are used to try and forecast this power output. Initially I presume SARIMA would be the most logical given the seasonal nature of the data but as you will see it was not the best by a long shot. I also used XGBoost and RandomForest regressors which proved the best. Lastly and exploration using an LSTM was done although the results for that were disappointing. There is the standard data exploration too !

# %%
#  !pip install pmdarima
#  !pip install pandas_profiling

# %%
#  !pip install xgboost
#  !pip install tensorflow

# %%
# import packages
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import math
from scipy.optimize import curve_fit
import ydata_profiling
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm # for SARIMAX algorith

import xgboost as xgb # for XGBoost algorith
from sklearn.ensemble import RandomForestRegressor # for RandomForest regressor
# LSTM imports
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping
# for scaling
from sklearn.preprocessing import MinMaxScaler

# %%
# to get the plots to show in the same size
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18,8)

# %% [markdown]
# # Import the data
# by viewing the csv the column Unnamed:0 is the date column so import it as such and then set it as a datetime

# %%
# import the data and set the time column as the index

df = pd.read_csv(r'C:\Users\ishan\Data Anaytics\Wind Data\Wind Data\Turbine_Data.csv', parse_dates=['Unnamed: 0'], index_col=['Unnamed: 0'])

# %%
df.index = pd.to_datetime(df.index)

# %%
df.columns
# Out:
# Index(['ActivePower', 'AmbientTemperatue', 'BearingShaftTemperature',
#        'Blade1PitchAngle', 'Blade2PitchAngle', 'Blade3PitchAngle',
#        'ControlBoxTemperature', 'GearboxBearingTemperature',
#        'GearboxOilTemperature', 'GeneratorRPM', 'GeneratorWinding1Temperature',
#        'GeneratorWinding2Temperature', 'HubTemperature', 'MainBoxTemperature',
#        'NacellePosition', 'ReactivePower', 'RotorRPM', 'TurbineStatus', 'WTG',
#        'WindDirection', 'WindSpeed'],
#       dtype='object')

# %%
df
# Out:
#                            ActivePower  AmbientTemperatue  \
# 2017-12-31 00:00:00+00:00          NaN                NaN
# 2017-12-31 00:10:00+00:00          NaN                NaN
# 2017-12-31 00:20:00+00:00          NaN                NaN
# 2017-12-31 00:30:00+00:00          NaN                NaN
# 2017-12-31 00:40:00+00:00          NaN                NaN
# ...                                ...                ...
# 2020-03-30 23:10:00+00:00    70.044465          27.523741
# 2020-03-30 23:20:00+00:00    40.833474          27.602882
# 2020-03-30 23:30:00+00:00    20.777790          27.560925
# 2020-03-30 23:40:00+00:00    62.091039          27.810472
# 2020-03-30 23:50:00+00:00    68.664425          27.915828
#
#                            BearingShaftTemperature  Blade1PitchAngle  \
# 2017-12-31 00:00:00+00:00                      NaN               NaN
# 2017-12-31 00:10:00+00:00                      NaN               NaN
# 2017-12-31 00:20:00+00:00                      NaN               NaN
# 2017-12-31 00:30:00+00:00                      NaN               NaN
# 2017-12-31 00:40:00+00:00                      NaN               NaN
# ...                                            ...               ...
# 2020-03-30 23:10:00+00:00                45.711129          1.515669
# 2020-03-30 23:20:00+00:00                45.598573          1.702809
# 2020-03-30 23:30:00+00:00                45.462045          1.706214
# 2020-03-30 23:40:00+00:00                45.343827          1.575352
# 2020-03-30 23:50:00+00:00                45.231610          1.499323
#
#                            Blade2PitchAngle  Blade3PitchAngle  \
# 2017-12-31 00:00:00+00:00               NaN               NaN
# 2017-12-31 00:10:00+00:00               NaN               NaN
# 2017-12-31 00:20:00+00:00               NaN               NaN
# 2017-12-31 00:30:00+00:00               NaN               NaN
# 2017-12-31 00:40:00+00:00               NaN               NaN
# ...                                     ...               ...
# 2020-03-30 23:10:00+00:00          1.950088          1.950088
# 2020-03-30 23:20:00+00:00          2.136732          2.136732
# 2020-03-30 23:30:00+00:00          2.139664          2.139664
# 2020-03-30 23:40:00+00:00          2.009781          2.009781
# 2020-03-30 23:50:00+00:00          1.933124          1.933124
#
#                            ControlBoxTemperature  GearboxBearingTemperature  \
# 2017-12-31 00:00:00+00:00                    NaN                        NaN
# 2017-12-31 00:10:00+00:00                    NaN                        NaN
# 2017-12-31 00:20:00+00:00                    NaN                        NaN
# 2017-12-31 00:30:00+00:00                    NaN                        NaN
# 2017-12-31 00:40:00+00:00                    NaN                        NaN
# ...                                          ...                        ...
# 2020-03-30 23:10:00+00:00                    0.0                  59.821165
# 2020-03-30 23:20:00+00:00                    0.0                  59.142038
# 2020-03-30 23:30:00+00:00                    0.0                  58.439439
# 2020-03-30 23:40:00+00:00                    0.0                  58.205413
# 2020-03-30 23:50:00+00:00                    0.0                  58.581716
#
#                            GearboxOilTemperature  GeneratorRPM  ...  \
# 2017-12-31 00:00:00+00:00                    NaN           NaN  ...
# 2017-12-31 00:10:00+00:00                    NaN           NaN  ...
# 2017-12-31 00:20:00+00:00                    NaN           NaN  ...
# 2017-12-31 00:30:00+00:00                    NaN           NaN  ...
# 2017-12-31 00:40:00+00:00                    NaN           NaN  ...
# ...                                          ...           ...  ...
# 2020-03-30 23:10:00+00:00              55.193793   1029.870744  ...
# 2020-03-30 23:20:00+00:00              54.798545   1030.160478  ...
# 2020-03-30 23:30:00+00:00              54.380456   1030.137822  ...
# 2020-03-30 23:40:00+00:00              54.079014   1030.178178  ...
# 2020-03-30 23:50:00+00:00              54.080505   1029.834789  ...
#
#                            GeneratorWinding2Temperature  HubTemperature  \
# 2017-12-31 00:00:00+00:00                           NaN             NaN
# 2017-12-31 00:10:00+00:00                           NaN             NaN
# 2017-12-31 00:20:00+00:00                           NaN             NaN
# 2017-12-31 00:30:00+00:00                           NaN             NaN
# 2017-12-31 00:40:00+00:00                           NaN             NaN
# ...                                                 ...             ...
# 2020-03-30 23:10:00+00:00                     58.148777       39.008931
# 2020-03-30 23:20:00+00:00                     57.550367       39.006759
# 2020-03-30 23:30:00+00:00                     57.099335       39.003815
# 2020-03-30 23:40:00+00:00                     56.847239       39.003815
# 2020-03-30 23:50:00+00:00                     56.741040       39.003815
#
#                            MainBoxTemperature  NacellePosition  ReactivePower  \
# 2017-12-31 00:00:00+00:00                 NaN              NaN            NaN
# 2017-12-31 00:10:00+00:00                 NaN              NaN            NaN
# 2017-12-31 00:20:00+00:00                 NaN              NaN            NaN
# 2017-12-31 00:30:00+00:00                 NaN              NaN            NaN
# 2017-12-31 00:40:00+00:00                 NaN              NaN            NaN
# ...                                       ...              ...            ...
# 2020-03-30 23:10:00+00:00           36.476562            178.0      13.775785
# 2020-03-30 23:20:00+00:00           36.328125            178.0       8.088928
# 2020-03-30 23:30:00+00:00           36.131944            178.0       4.355978
# 2020-03-30 23:40:00+00:00           36.007805            190.0      12.018077
# 2020-03-30 23:50:00+00:00           35.914062            203.0      14.439669
#
#                            RotorRPM  TurbineStatus  WTG WindDirection  \
# 2017-12-31 00:00:00+00:00       NaN            NaN  G01           NaN
# 2017-12-31 00:10:00+00:00       NaN            NaN  G01           NaN
# 2017-12-31 00:20:00+00:00       NaN            NaN  G01           NaN
# 2017-12-31 00:30:00+00:00       NaN            NaN  G01           NaN
# 2017-12-31 00:40:00+00:00       NaN            NaN  G01           NaN
# ...                             ...            ...  ...           ...
# 2020-03-30 23:10:00+00:00  9.234004            2.0  G01         178.0
# 2020-03-30 23:20:00+00:00  9.229370            2.0  G01         178.0
# 2020-03-30 23:30:00+00:00  9.236802            2.0  G01         178.0
# 2020-03-30 23:40:00+00:00  9.237374            2.0  G01         190.0
# 2020-03-30 23:50:00+00:00  9.235532            2.0  G01         203.0
#
#                            WindSpeed
# 2017-12-31 00:00:00+00:00        NaN
# 2017-12-31 00:10:00+00:00        NaN
# 2017-12-31 00:20:00+00:00        NaN
# 2017-12-31 00:30:00+00:00        NaN
# 2017-12-31 00:40:00+00:00        NaN
# ...                              ...
# 2020-03-30 23:10:00+00:00   3.533445
# 2020-03-30 23:20:00+00:00   3.261231
# 2020-03-30 23:30:00+00:00   3.331839
# 2020-03-30 23:40:00+00:00   3.284468
# 2020-03-30 23:50:00+00:00   3.475205
#
# [118224 rows x 21 columns]

# %%
# total number of values in the data frame - 118224
len(df)
# Out:
# 118224

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 23039

# %% [markdown]
# ## Check for duplicate entries
# 23039 duplicates, when droped the df has 95185 unique entries

# %%
# drop the duplicates
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 95185

# %% [markdown]
# # Exploratory data analysis - using pandas profiling and then some boxplots.
#
# Distributions of the data for each variable can be seen along with the missing values by using the pandas profiling package - also ControlBoxTemperature and WTG are not a useful.
#
# A correlation graph is shown but I derive one later and explain things further. Also check for duplicates and drop them is there are any.
#
# Also note box plot for ActivePower goes below zero - it means turbine is drawing power form grid instead of supplying.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 95185 entries, 2017-12-31 00:00:00+00:00 to 2020-03-30 23:50:00+00:00
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ActivePower                   94624 non-null  float64
#  1   AmbientTemperatue             93698 non-null  float64
#  2   BearingShaftTemperature       62380 non-null  float64
#  3   Blade1PitchAngle              41987 non-null  float64
#  4   Blade2PitchAngle              41882 non-null  float64
#  5   Blade3PitchAngle              41882 non-null  float64
#  6   ControlBoxTemperature         62022 non-null  float64
#  7   GearboxBearingTemperature     62402 non-null  float64
#  8   GearboxOilTemperature         62430 non-null  float64
#  9   GeneratorRPM                  62287 non-null  float64
#  10  GeneratorWinding1Temperature  62419 non-null  float64
#  11  GeneratorWinding2Temperature  62441 non-null  float64
#  12  HubTemperature                62268 non-null  float64
#  13  MainBoxTemperature            62369 non-null  float64
#  14  NacellePosition               72108 non-null  float64
#  15  ReactivePower                 94622 non-null  float64
#  16  RotorRPM                      62119 non-null  float64
#  17  TurbineStatus                 62759 non-null  float64
#  18  WTG                           95185 non-null  object
#  19  WindDirection                 72108 non-null  float64
#  20  WindSpeed                     94469 non-null  float64
# dtypes: float64(20), object(1)
# memory usage: 16.0+ MB

# %%
df.describe()
# Out:
#         ActivePower  AmbientTemperatue  BearingShaftTemperature  \
# count  94624.000000       93698.000000             62380.000000
# mean     619.036994          28.777569                43.105338
# std      610.917748           4.358470                 5.168850
# min      -38.524659           0.000000                 0.000000
# 25%       80.098952          25.625603                39.856871
# 50%      402.880706          28.338961                42.927465
# 75%     1073.979105          31.665910                47.018075
# max     1779.032433          42.405597                55.088655
#
#        Blade1PitchAngle  Blade2PitchAngle  Blade3PitchAngle  \
# count      41987.000000      41882.000000      41882.000000
# mean           9.751759         10.038709         10.038709
# std           20.646533         20.272100         20.272100
# min          -43.156734        -26.443415        -26.443415
# 25%           -0.939896         -0.433316         -0.433316
# 50%            0.395038          0.889782          0.889782
# 75%            8.101939          8.481306          8.481306
# max           90.143610         90.017830         90.017830
#
#        ControlBoxTemperature  GearboxBearingTemperature  \
# count                62022.0               62402.000000
# mean                     0.0                  64.376222
# std                      0.0                  10.020754
# min                      0.0                   0.000000
# 25%                      0.0                  57.925129
# 50%                      0.0                  64.862406
# 75%                      0.0                  71.104401
# max                      0.0                  82.237932
#
#        GearboxOilTemperature  GeneratorRPM  GeneratorWinding1Temperature  \
# count           62430.000000  62287.000000                  62419.000000
# mean               57.561706   1102.146658                     72.462897
# std                 6.324124    527.967896                     22.626685
# min                 0.000000      0.000000                      0.000000
# 25%                53.944023   1029.812895                     55.492241
# 50%                57.197064   1124.930500                     65.792061
# 75%                61.307270   1515.517020                     85.874609
# max                70.764581   1809.941700                    126.773031
#
#        GeneratorWinding2Temperature  HubTemperature  MainBoxTemperature  \
# count                  62441.000000    62268.000000        62369.000000
# mean                      71.829134       36.979752           39.635107
# std                       22.649494        4.884101            5.428555
# min                        0.000000        0.000000            0.000000
# 25%                       54.763998       33.977709           35.843574
# 50%                       65.006679       37.003815           39.500759
# 75%                       85.342714       40.009538           43.370342
# max                      126.043018       47.996185           54.250000
#
#        NacellePosition  ReactivePower      RotorRPM  TurbineStatus  \
# count     72108.000000   94622.000000  62119.000000   6.275900e+04
# mean        196.307894      88.070309      9.908585   2.284016e+03
# std          88.279316     116.498176      4.717546   3.590288e+05
# min           0.000000    -203.182591      0.000000   0.000000e+00
# 25%         145.000000      -0.433723      9.231097   2.000000e+00
# 50%         182.000000      35.938526     10.099272   2.000000e+00
# 75%         271.000000     147.190453     13.600908   2.000000e+00
# max         357.000000     403.713620     16.273495   6.574653e+07
#
#        WindDirection     WindSpeed
# count   72108.000000  94469.000000
# mean      196.307894      5.879193
# std        88.279316      2.617241
# min         0.000000      0.000000
# 25%       145.000000      3.824572
# 50%       182.000000      5.558520
# 75%       271.000000      7.505555
# max       357.000000     22.970893

# %%
# Use panda_profiling library to investigate the data
ydata_profiling.ProfileReport(df)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[156], line 2
#       1 # Use panda_profiling library to investigate the data
# ----> 2 ydata_profiling.ProfileReport(df)
#
# File ~\anaconda3\lib\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~\anaconda3\lib\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\anaconda3\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:518, in ProfileReport._repr_html_(self)
#     516 def _repr_html_(self) -> None:
#     517     """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 518     self.to_notebook_iframe()
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:498, in ProfileReport.to_notebook_iframe(self)
#     496 with warnings.catch_warnings():
#     497     warnings.simplefilter("ignore")
# --> 498     display(get_notebook_iframe(self.config, self))
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:468, in ProfileReport.to_html(self)
#     460 def to_html(self) -> str:
#     461     """Generate and return complete template as lengthy string
#     462         for using with frameworks.
#     463
#    (...)
#     466
#     467     """
# --> 468     return self.html
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:275, in ProfileReport.html(self)
#     272 @property
#     273 def html(self) -> str:
#     274     if self._html is None:
# --> 275         self._html = self._render_html()
#     276     return self._html
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:383, in ProfileReport._render_html(self)
#     380 def _render_html(self) -> str:
#     381     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 383     report = self.report
#     385     with tqdm(
#     386         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     387     ) as pbar:
#     388         html = HTMLReport(copy.deepcopy(report)).render(
#     389             nav=self.config.html.navbar_show,
#     390             offline=self.config.html.use_local_assets,
#    (...)
#     398             version=self.description_set.package["ydata_profiling_version"],
#     399         )
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:269, in ProfileReport.report(self)
#     266 @property
#     267 def report(self) -> Root:
#     268     if self._report is None:
# --> 269         self._report = get_report_structure(self.config, self.description_set)
#     270     return self._report
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\profile_report.py:251, in ProfileReport.description_set(self)
#     248 @property
#     249 def description_set(self) -> BaseDescription:
#     250     if self._description_set is None:
# --> 251         self._description_set = describe_df(
#     252             self.config,
#     253             self.df,
#     254             self.summarizer,
#     255             self.typeset,
#     256             self._sample,
#     257         )
#     258     return self._description_set
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\model\describe.py:128, in describe(config, df, summarizer, typeset, sample)
#     124 scatter_matrix: Dict[Any, Dict[Any, Any]] = {
#     125     x: {y: None} for x, y in scatter_tasks
#     126 }
#     127 for x, y in scatter_tasks:
# --> 128     scatter_matrix[x][y] = progress(
#     129         get_scatter_plot, pbar, f"scatter {x}, {y}"
#     130     )(config, df, x, y, interval_columns)
#     132 # missing diagrams
#     133 missing_map = get_missing_active(config, table_stats)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\utils\progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\model\pairwise.py:31, in get_scatter_plot(config, df, x, y, continuous_variables)
#      29     else:
#      30         df_temp = df[[x, y]].dropna()
# ---> 31     return scatter_pairwise(config, df_temp[x], df_temp[y], x, y)
#      32 else:
#      33     return ""
#
# File ~\anaconda3\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\visualisation\plot.py:366, in scatter_pairwise(config, series1, series2, x_label, y_label)
#     364 else:
#     365     plt.scatter(series1[indices], series2[indices], color=color)
# --> 366 return plot_360_n0sc0pe(config)
#
# File ~\anaconda3\lib\site-packages\ydata_profiling\visualisation\utils.py:73, in plot_360_n0sc0pe(config, image_format, bbox_extra_artists, bbox_inches)
#      70 if image_format == "svg":
#      71     image_str = StringIO()
# ---> 73     plt.savefig(
#      74         image_str,
#      75         format=image_format,
#      76         bbox_extra_artists=bbox_extra_artists,
#      77         bbox_inches=bbox_inches,
#      78     )
#      79     plt.close()
#      80     result_string = image_str.getvalue()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:996, in savefig(*args, **kwargs)
#     993 @_copy_docstring_and_deprecators(Figure.savefig)
#     994 def savefig(*args, **kwargs):
#     995     fig = gcf()
# --> 996     res = fig.savefig(*args, **kwargs)
#     997     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     998     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3328, in Figure.savefig(self, fname, transparent, **kwargs)
#    3324     for ax in self.axes:
#    3325         stack.enter_context(
#    3326             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3328 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_svg.py:1369, in FigureCanvasSVG.print_svg(self, filename, bbox_inches_restore, metadata)
#    1364 w, h = width * 72, height * 72
#    1365 renderer = MixedModeRenderer(
#    1366     self.figure, width, height, dpi,
#    1367     RendererSVG(w, h, fh, image_dpi=dpi, metadata=metadata),
#    1368     bbox_inches_restore=bbox_inches_restore)
# -> 1369 self.figure.draw(renderer)
#    1370 renderer.finalize()
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3125, in Figure.draw(self, renderer)
#    3122         # ValueError can occur when resizing a window.
#    3124 self.patch.draw(renderer)
# -> 3125 mimage._draw_list_compositing_images(
#    3126     renderer, self, artists, self.suppressComposite)
#    3128 for sfig in self.subfigs:
#    3129     sfig.draw(renderer)
#
# File ~\anaconda3\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3030, in _AxesBase.draw(self, renderer)
#    3027     for spine in self.spines.values():
#    3028         artists.remove(spine)
# -> 3030 self._update_title_position(renderer)
#    3032 if not self.axison:
#    3033     for _axis in self._axis_map.values():
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2965, in _AxesBase._update_title_position(self, renderer)
#    2962 bb = None
#    2963 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2964         or ax.xaxis.get_label_position() == 'top'):
# -> 2965     bb = ax.xaxis.get_tightbbox(renderer)
#    2966 if bb is None:
#    2967     if 'outline' in ax.spines:
#    2968         # Special case for colorbars:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1318, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1316 if renderer is None:
#    1317     renderer = self.figure._get_renderer()
# -> 1318 ticks_to_draw = self._update_ticks()
#    1320 self._update_label_position(renderer)
#    1322 # go back to just this axis's tick labels
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1265, in Axis._update_ticks(self)
#    1263     tick.set_label1(label)
#    1264     tick.set_label2(label)
# -> 1265 minor_locs = self.get_minorticklocs()
#    1266 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1267 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1486, in Axis.get_minorticklocs(self)
#    1484 minor_locs = np.asarray(self.minor.locator())
#    1485 if self.remove_overlapping_locs:
# -> 1486     major_locs = self.major.locator()
#    1487     transform = self._scale.get_transform()
#    1488     tr_minor_locs = transform.transform(minor_locs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\ticker.py:2136, in MaxNLocator.__call__(self)
#    2134 def __call__(self):
#    2135     vmin, vmax = self.axis.get_view_interval()
# -> 2136     return self.tick_values(vmin, vmax)
#
# File ~\anaconda3\lib\site-packages\matplotlib\ticker.py:2144, in MaxNLocator.tick_values(self, vmin, vmax)
#    2141     vmin = -vmax
#    2142 vmin, vmax = mtransforms.nonsingular(
#    2143     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2144 locs = self._raw_ticks(vmin, vmax)
#    2146 prune = self._prune
#    2147 if prune == 'lower':
#
# File ~\anaconda3\lib\site-packages\matplotlib\ticker.py:2083, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2081 if self._nbins == 'auto':
#    2082     if self.axis is not None:
# -> 2083         nbins = np.clip(self.axis.get_tick_space(),
#    2084                         max(1, self._min_n_ticks - 1), 9)
#    2085     else:
#    2086         nbins = 9
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:2479, in XAxis.get_tick_space(self)
#    2478 def get_tick_space(self):
# -> 2479     ends = mtransforms.Bbox.unit().transformed(
#    2480         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2481     length = ends.width * 72
#    2482     # There is a heuristic here that the aspect ratio of tick text
#    2483     # is no more than 3:1
#
# File ~\anaconda3\lib\site-packages\matplotlib\transforms.py:479, in BboxBase.transformed(self, transform)
#     475 """
#     476 Construct a `Bbox` by statically transforming this one by *transform*.
#     477 """
#     478 pts = self.get_points()
# --> 479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     481 return Bbox([ll, [lr[0], ul[1]]])
#
# File ~\anaconda3\lib\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File ~\anaconda3\lib\site-packages\matplotlib\transforms.py:2415, in CompositeGenericTransform.transform_affine(self, points)
#    2413 def transform_affine(self, points):
#    2414     # docstring inherited
# -> 2415     return self.get_affine().transform(points)
#
# File ~\anaconda3\lib\site-packages\matplotlib\transforms.py:2441, in CompositeGenericTransform.get_affine(self)
#    2439     return self._b.get_affine()
#    2440 else:
# -> 2441     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2442                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# Need to drop WTG column as it is always G01
df.drop('WTG', axis=1, inplace=True)
df.drop('ControlBoxTemperature', axis=1, inplace=True)

# %%
df.columns

# %%
# Boxplots of all the data
for column in df:    
    fig,ax = plt.subplots(figsize=(18,1.5))
    sns.boxplot(data=df, x=column)

# %% [markdown]
# # Handling missing values
# There are missing values for all fields with 2018 having the most missing data. If we look at the ActivePower field there is roughly 0.6% of the data missing (561/94750) - there should be enough for a reasonable prediction (the nas will be dropped once the dataset is reduced) - no need to impute missing values.

# %%
# from the above panda profile there are lots os missing values - a quick summary is given below
df.isna().sum()

# %%
# Look at this for each year to see if more data is missing for different years.
for yr in df.index.year.unique():
    print('\nYear',yr,'\n', df[df.index.year==yr].isna().sum())

# %% [markdown]
# The last thing to check is if there are any negative values for ActivePower. There are in fact 15629 entries with negative 'ActivePower'. These all seem quite arbitary, as they seem to happen over a significant range of wind speed and generator RPM, to both of which it should be proportional. All entries seem to happen at low wind speed, but however, there are occasions with similar windspeeds and the ActivePower is 0 so it is likely they are a incorrect readings and so they will be dropped

# %%
# check entries with negative values for ActivePower  - for comparison can also use df['ActivePower']==0 to see wind speeds when no power generated
cols = ['ActivePower','WindSpeed','GeneratorRPM']
df[cols][df['ActivePower']<0]

# %%
# Now to remove the negative ActivePower values
cols = ['ActivePower','WindSpeed']
df =  df[df['ActivePower']>=0]

# %%
# total number of NaN Activepower readings
total_na = df['ActivePower'].isna().sum()  # 0
# count the number of non na values
total = df['ActivePower'].count()          # 78698
# percentage missing 
print('Percentage of missing values {}%'.format(round(total_na/total,2)*100))     # 0.0

# %% [markdown]
# # Graphing power production
#  First using all the data first (but as there is a reading every 10 minutes it is very messy), then resampling the mean daily values to view more clearly.
# A pattern emerges from the daily mean data, there are power output maxima in July, August and September.Graph

# %%
# Power output 
df['ActivePower'].plot()
plt.ylabel('Power Generated', fontsize=18)

# %%
# Resampling daily
df['ActivePower'].resample('D').mean().plot()
plt.ylabel('Mean Daily Power Generated', fontsize=18)

# %% [markdown]
# Obviously a wind turbine is going to generate the most power in windy conditions so now plot the daily mean wind (the missing values can be seen) to see if there is a similar pattern in the graph

# %%
# resampling monthly
df['WindSpeed'].resample('D').mean().plot(color='orange')
plt.ylabel('Wind Speed', fontsize=18)

# %% [markdown]
# # Graph together
# If both above graphs are overlaid - with wind speed multiplied by 100 to get to the same scale the pattern and correlation is easily evident. Daily and monthly resampling values are graphed to make the point. But the correlation is obvious.

# %%
# Graph together
df['ActivePower'].resample('D').mean().plot(legend=True)
(df['WindSpeed']*100).resample('D').mean().plot(legend=True)
plt.ylabel('Active pPower and Wind speed*100', fontsize=18)

# %%
# Graph together
df['ActivePower'].resample('M').mean().plot(legend=True)
(df['WindSpeed']*100).resample('M').mean().plot(legend=True)
plt.ylabel('Active pPower and Wind speed*100', fontsize=18)

# %% [markdown]
# # What about other correlations ?

# %%
# To find the correlation among the columns using pearson method 

corr_matrix = df.corr().round(2) # add .abs() if not worried about positive or negative correlation just the strength

# use this to show only lower triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
cut_off = -1 # to show all correlations

mask |= np.abs(corr_matrix) < cut_off
corr = corr_matrix[~mask]  # fill in NaN in the non-desired cells
# reove empty rows/columns to make it easier to read.
remove_empty_rows_and_cols = True
if remove_empty_rows_and_cols:
    wanted_cols = np.flatnonzero(np.count_nonzero(~mask, axis=1))
    wanted_rows = np.flatnonzero(np.count_nonzero(~mask, axis=0))
    corr = corr.iloc[wanted_cols, wanted_rows]
# display the correlation value in a grid to make it easier to read.
s = sns.heatmap(corr,annot=True,  linewidths=0.1, linecolor='gray', cmap="BrBG")
# increase the size of the labels.
s.set_title('Correlation Heatmap (all correlations)', fontsize=40)
s.set_xticklabels(s.get_xmajorticklabels(), fontsize = 15)
s.set_yticklabels(s.get_ymajorticklabels(), fontsize = 15)
plt.show()

# %%
# Another way of viewing specific correlations
correlations = df.corr().unstack().sort_values(ascending=False) 

# checking  ActivePower correlations
correlations['ActivePower'].drop_duplicates()  # change the required field here to get the specific correlations

# %% [markdown]
# Drop the columns that are not correlated to the ActivePower column and also some columns that are correlated to each other. In fact the only features that are not related to the turbine - such as GearBoxOilTemperature for example - are the ambient temperature, the wind speed and wind direction (which make sense since it is a wind turtbine that uses the wind to generate power !!). Wind direction and ambient temperature are only correlated in a very minor way. So let's just keep the wind speed and see how that goes (and now the NaNs can be dropped coincidentally WindSpeed has the least NaN values compared to the other fields).

# %%
data = df[['ActivePower','WindSpeed']]
# now to drop the na values
data = df.dropna()

# %% [markdown]
# # Look for a pattern of power generation versus wind speed.
# Here we can see that the wind speed needs to be about 2.5m/s to turn the turbine and start generating power. And the maximum wind power is generated at about 8m/s - wind speeds fater than that do not generate any more power (this must be a function of the turbine).
#
# There is some noise in the graph but a fairly simple function can be used to describe the data. It is almost linear but a Sigmoid function (exponential) will capture the minimum and maximum features better
#
# I had discovered this feature whilst doing another kaggle entry - see it here - https://www.kaggle.com/code/chrismat10/texas-turbine-regression-and-curve-fit

# %%
data.plot.scatter(y='ActivePower', x='WindSpeed')
plt.title('Power output versus wind speed', fontsize=34 )

# %%
# The graph has the same shape as the one above.

X = np.arange(0, 20, 0.1)
Y = 1725 / (1.0 + np.exp(0.9*(-X+3.5)))
plt.plot(X,Y) 
plt.show()

# %% [markdown]
# ## Solving for Parameters
# Define a function to plot this graph and then use curve_fit from scipy to solve for the optimal parameters and finally graph against the measured values. Transparency of measured values is set very low - hence the outliers look like they have disappeared

# %%
# Define a funcation for the graph to be used for prediction - 
def graph_func(X,c1,c2):
    return 1725 / (1.0 + np.exp(c1*(-X+c2)))

# %%
# define and empty array to put the power predictions into
n = len(df['WindSpeed'])
# first guess for the curve parameters - play around with these to get a better shaped curve
c = [0.5, 5]
predicted_power = np.empty(n)
for i in range(n):
    predicted_power[i] = graph_func(data['WindSpeed'][i],c[0],c[1]) # use initial guesses
    
plt.plot(data['WindSpeed'],predicted_power,'r.')
plt.plot(data['WindSpeed'],data['ActivePower'],'b.', alpha=0.5 )
plt.ylabel('System power generated | (kW)', fontsize=18)
plt.xlabel('Windspeed m/s', fontsize=18)
plt.title('Power output versus wind speed', fontsize=34 )
plt.legend(['Predicted','Actual'], fontsize=14)

# %%
from scipy.optimize import curve_fit, leastsq

# %%
# now to use curve_fit

c,cov = curve_fit(graph_func,data['WindSpeed'],data['ActivePower'],[0.5,5])
print(c)

# %% [markdown]
# ## Now to do the plot again with the new curve_fit solved values

# %%
# define and empty array to put the power predictions into
n = len(data['WindSpeed'])

predicted_power = np.empty(n)
for i in range(n):
    predicted_power[i] = graph_func(data['WindSpeed'][i],c[0],c[1]) # use values calculated in the curve_fit equation above
    
plt.plot(data['WindSpeed'],predicted_power,'r.')
plt.plot(data['WindSpeed'],data['ActivePower'],'b.', alpha=0.01 )
plt.ylabel('System power generated | (kW)', fontsize=18)
plt.xlabel('Windspeed m/s', fontsize=18)
plt.title('Power output versus wind speed', fontsize=34 )
plt.legend(['Predicted','Actual'], fontsize=14)

# %% [markdown]
# # Accuracy statistics
# The R squared is excellent for this method - and so with the next 15 days wind speeds we could easily forecast the power output with 97% accuracy.

# %%
print('The Coefficient of determination (R-squared) = {:.2f}'.format(r2_score(data['ActivePower'],predicted_power)))
print('The mean absolute error (MAE) for            = {:.2f}'.format(mean_absolute_error(data['ActivePower'],predicted_power)))
print('The RMSE error (RMSE) for                    = {:.2f}'.format(mean_squared_error(data['ActivePower'],predicted_power, squared=False)))

# %% [markdown]
# # However, this was not the task here - as stated in the dataset context -
#
# 'A long term wind forecasting technique is thus required'. So based on 2 and a bit years worth of data the wind for the next 15 days should be forecast - and hence the wind power that can be generated.
#
# As this is time series analysis with an obvious seasonal component - shown in the monthly graphs below (max in June, July and August for power generation and wind) - some time series techniques need to be employed.

# %%
# Now to visualise amount generated by month
sns.boxplot(x=df.index.month_name(), y='ActivePower', data=df, palette="twilight")
plt.ylabel('ActivePower', fontsize=24)
plt.xlabel('Month', fontsize=24)
plt.title("Monthly boxplots of Power Generated", fontsize=34)

# %%
# Now to visualise amount generated by month
sns.boxplot(x=df.index.month_name(), y='WindSpeed', data=df, palette="twilight")
plt.ylabel('WindSpeed', fontsize=24)
plt.xlabel('Month', fontsize=24)
plt.title("Monthly boxplots of Wind Speed", fontsize=34)

# %% [markdown]
# ## Graph of hourly power generation - shows as expected it is generally windier in the afternoon and hence more power is generated in the afternoon - but it can be generated at any time of course..

# %%
# Now to visualise amount generated by hour
sns.boxplot(x=df.index.hour, y='WindSpeed', data=df, palette="PuRd")
plt.ylabel('WindSpeed', fontsize=24)
plt.xlabel('Hour', fontsize=24)
plt.title("Hourly boxplots of Wind Speed", fontsize=34)

# %% [markdown]
# ## Since the graphs above show aseasonal component a simple ARIMA model can't be used but a Seasonal ARIMA or SARIMA can. The other conditions for SARIMA is that it is univariate which is what I have done by only looking at the wind speed for the power output. The SARIMA model uses the same 3 elements of ARIMA, plus 4 additional seasonal variable.
#
# ![image.png](attachment:1d0b2ecd-b9af-42ec-9135-cbc20912d6d8.png)

# %% [markdown]
# ## The graphs above show a definitive seasonality (as expected !)
#
# ## Using the Dicker-Fuller test we can test to stationality, a p value of 1.04x10^(-28) is much smaller than 0.05 and so even though the data is seasonal it is stationary.

# %%
# Dicker-Fuller test
dftest = adfuller(df.ActivePower, autolag = 'AIC')
print(" ADF : ",dftest[0])
print(" p-Value : ", dftest[1])
print(" Num Of Lags : ", dftest[2])
print(" Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print(" Critical Values :")
for key, val in dftest[4].items():
    print("\t",key, ": ", val)

# %% [markdown]
# ## The values of each of the required parameters p,d,q, P,D,Q and m can be worked out using the auto_arima function. However, since it is stationary the d value is 0.
#
# ## First to resample the data to daily as that is what we are trying to predict - the next 15 days worth of power generated.

# %%
# Since we want to simplify resample per day
df_daily  = df[['ActivePower','WindSpeed']].resample('D').mean()
df_daily.dropna(inplace=True) # drop and nas than get introduced

# %%
len(df_daily)

# %% [markdown]
# ## Further evidence of the seasonal nature of the data set can be seen using the seasonal decompose function and setting the period = to 31 (a month)

# %%
# decompase into seasonal/trend/residual
result = seasonal_decompose(df_daily['ActivePower'].dropna(), period=31, model='additive',extrapolate_trend=True)
result.plot()
plt.show()

# %%
model=pm.auto_arima(df_daily['ActivePower'],start_p=0,d=0,start_q=0,
          max_p=15,max_q=5, 
          start_P=0,D=0, start_Q=0, 
          max_P=8, max_Q=8, 
          m=12, seasonal=True, stationary=True,
          error_action='warn',trace=True,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=100)

# %%
model.summary()

# %%
# Set up the SARIMA model with values as above
p = 6
d = 0
q = 0
P = 0
D = 0
Q = 0
m = 12

model = SARIMAX(df_daily['ActivePower'], order=(p,d,q), seasonal_order=(P,D,Q,m)) #- based on model.summary above we don't need the seasonal order part
model_fit = model.fit(disp=0) # disp=0 so no display
    
pred_day = model_fit.predict(start=1, end=len(df_daily['ActivePower']))

# %%
# make sure they have the same index (otherwise pred index gets set to 1970-01-01)
pred_day.index = df_daily['ActivePower'].index

# %%
df_final = pd.DataFrame(data={'Predictions':pred_day, 'Actuals':df_daily['ActivePower'] })  
df_final.head()

# %%
print('The Coefficient of determination (R-squared) = {:.2f}'.format(r2_score(df_final['Actuals'],df_final['Predictions'])))
print('The mean absolute error (MAE)                = {:.2f}'.format(mean_absolute_error(df_final['Actuals'],df_final['Predictions'])))
print('The RMSE error (RMSE)                        = {:.2f}'.format(mean_squared_error(df_final['Actuals'],df_final['Predictions'], squared=False)))
print('The Mean absolute percentage error (MAPE)    = {:.2f}'.format(mean_absolute_percentage_error(df_final['Actuals'],df_final['Predictions'])))

# %% [markdown]
# ## A graph using the whole dataset is shown below

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
#   # These results are very good but are based on the whole dataset - that is training the model on the whole dataset and then predicting on the same dataset that has already been used to learn - so of course the results are great - they should be.
#
# ## The next step is to forecast for the next 15 days. To do this I will set up 3 groups of training and testing data.
#
# ## The whole dataset minus the last 15 days as the test set.
# ## 80% of the data as train and then 15 days after that as test
# ## Two thirds of the data as training and then 15 days after that as test and then compare results.
#
# ## The results are not very good !
#
# ## Work out the number of observations and then work from there - 748

# %%
# work out the number of observations
len(df_daily['ActivePower'])

# %%
# train is from 0 to 733 test is from 733 to 748

train, test = df_daily[0:733], df_daily[733:748]
len(train), len(test)

# %% [markdown]
# ## Repeat the steps as above

# %%
train, test
# Out:
# (                           ActivePower  WindSpeed
#  2018-01-01 00:00:00+00:00   366.223561   5.263797
#  2018-01-02 00:00:00+00:00   462.550740   5.390719
#  2018-01-03 00:00:00+00:00   454.417752   5.295225
#  2018-01-04 00:00:00+00:00   369.952190   5.094994
#  2018-01-05 00:00:00+00:00   319.446595   4.915224
#  ...                                ...        ...
#  2020-03-11 00:00:00+00:00   466.289248   5.385570
#  2020-03-12 00:00:00+00:00   570.315539   5.693483
#  2020-03-13 00:00:00+00:00   619.637333   5.765318
#  2020-03-14 00:00:00+00:00   800.312824   6.217917
#  2020-03-15 00:00:00+00:00   787.305117   6.458906
#
#  [733 rows x 2 columns],
#                             ActivePower  WindSpeed
#  2020-03-16 00:00:00+00:00   644.891382   5.908178
#  2020-03-17 00:00:00+00:00   857.485779   6.650817
#  2020-03-18 00:00:00+00:00   367.360814   5.127046
#  2020-03-19 00:00:00+00:00   629.455480   5.876625
#  2020-03-20 00:00:00+00:00   485.411496   5.589186
#  2020-03-21 00:00:00+00:00   432.529893   5.337225
#  2020-03-22 00:00:00+00:00   481.172384   5.492389
#  2020-03-23 00:00:00+00:00   552.187880   5.665710
#  2020-03-24 00:00:00+00:00   425.815287   5.344891
#  2020-03-25 00:00:00+00:00   754.076163   6.401851
#  2020-03-26 00:00:00+00:00   732.042233   6.245735
#  2020-03-27 00:00:00+00:00   728.896074   6.207374
#  2020-03-28 00:00:00+00:00   874.011580   6.776972
#  2020-03-29 00:00:00+00:00   840.439852   6.551854
#  2020-03-30 00:00:00+00:00   873.498776   6.605541)

# %%
# use auto_arima on the training data alone - interestingly different results
model=pm.auto_arima(train['ActivePower'],start_p=0,d=0,start_q=0,
          max_p=15,max_q=5, 
          start_P=0,D=0, start_Q=0, 
          max_P=8, max_Q=8, 
          m=12, seasonal=True, stationary=True,
          error_action='warn',trace=True,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=100)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=11058.797, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=9979.778, Time=0.56 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=10425.595, Time=0.40 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=11931.494, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=9981.930, Time=0.07 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=9978.485, Time=1.09 sec
#  ARIMA(1,0,0)(3,0,0)[12] intercept   : AIC=9977.295, Time=5.73 sec
#  ARIMA(1,0,0)(4,0,0)[12] intercept   : AIC=9978.917, Time=15.23 sec
#  ARIMA(1,0,0)(3,0,1)[12] intercept   : AIC=9979.221, Time=4.00 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=9978.341, Time=2.77 sec
#  ARIMA(1,0,0)(4,0,1)[12] intercept   : AIC=9980.731, Time=7.25 sec
#  ARIMA(0,0,0)(3,0,0)[12] intercept   : AIC=10743.838, Time=10.17 sec
#  ARIMA(2,0,0)(3,0,0)[12] intercept   : AIC=9965.880, Time=6.26 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=9966.522, Time=2.00 sec
#  ARIMA(2,0,0)(4,0,0)[12] intercept   : AIC=9967.811, Time=11.39 sec
#  ARIMA(2,0,0)(3,0,1)[12] intercept   : AIC=9967.872, Time=4.79 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=9968.349, Time=1.77 sec
#  ARIMA(2,0,0)(4,0,1)[12] intercept   : AIC=9969.746, Time=13.08 sec
#  ARIMA(3,0,0)(3,0,0)[12] intercept   : AIC=9962.113, Time=16.06 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=9962.498, Time=2.52 sec
#  ARIMA(3,0,0)(4,0,0)[12] intercept   : AIC=9964.038, Time=20.12 sec
#  ARIMA(3,0,0)(3,0,1)[12] intercept   : AIC=9964.112, Time=5.82 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=9964.327, Time=2.87 sec
#  ARIMA(3,0,0)(4,0,1)[12] intercept   : AIC=9966.014, Time=11.50 sec
#  ARIMA(4,0,0)(3,0,0)[12] intercept   : AIC=9956.076, Time=9.23 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : AIC=9956.223, Time=3.71 sec
#  ARIMA(4,0,0)(4,0,0)[12] intercept   : AIC=9957.966, Time=15.19 sec
#  ARIMA(4,0,0)(3,0,1)[12] intercept   : AIC=9958.073, Time=10.14 sec
#  ARIMA(4,0,0)(2,0,1)[12] intercept   : AIC=9958.108, Time=2.39 sec
#  ARIMA(4,0,0)(4,0,1)[12] intercept   : AIC=9959.953, Time=13.66 sec
#  ARIMA(5,0,0)(3,0,0)[12] intercept   : AIC=9954.841, Time=11.68 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : AIC=9954.898, Time=4.64 sec
#  ARIMA(5,0,0)(4,0,0)[12] intercept   : AIC=9956.823, Time=16.99 sec
#  ARIMA(5,0,0)(3,0,1)[12] intercept   : AIC=9956.840, Time=12.12 sec
#  ARIMA(5,0,0)(2,0,1)[12] intercept   : AIC=9956.806, Time=3.10 sec
#  ARIMA(5,0,0)(4,0,1)[12] intercept   : AIC=9958.815, Time=13.20 sec
#  ARIMA(6,0,0)(3,0,0)[12] intercept   : AIC=9952.098, Time=11.27 sec
#  ARIMA(6,0,0)(2,0,0)[12] intercept   : AIC=9952.251, Time=4.17 sec
#  ARIMA(6,0,0)(4,0,0)[12] intercept   : AIC=9954.093, Time=16.98 sec
#  ARIMA(6,0,0)(3,0,1)[12] intercept   : AIC=9954.092, Time=10.96 sec
#  ARIMA(6,0,0)(2,0,1)[12] intercept   : AIC=9954.114, Time=3.70 sec
#  ARIMA(6,0,0)(4,0,1)[12] intercept   : AIC=9956.083, Time=17.35 sec
#  ARIMA(7,0,0)(3,0,0)[12] intercept   : AIC=9952.825, Time=15.26 sec
#  ARIMA(6,0,1)(3,0,0)[12] intercept   : AIC=9953.799, Time=13.62 sec
#  ARIMA(5,0,1)(3,0,0)[12] intercept   : AIC=9955.555, Time=16.55 sec
#  ARIMA(7,0,1)(3,0,0)[12] intercept   : AIC=9954.475, Time=13.93 sec
#  ARIMA(6,0,0)(3,0,0)[12]             : AIC=9962.604, Time=3.30 sec
#
# Best model:  ARIMA(6,0,0)(3,0,0)[12] intercept
# Total fit time: 388.716 seconds

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  733
# Model:             SARIMAX(6, 0, 0)x(3, 0, 0, 12)   Log Likelihood               -4965.049
# Date:                            Sat, 08 Jul 2023   AIC                           9952.098
# Time:                                    19:02:15   BIC                          10002.666
# Sample:                                         0   HQIC                          9971.604
#                                             - 733
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     50.2842     17.711      2.839      0.005      15.572      84.996
# ar.L1          0.7073      0.032     22.071      0.000       0.644       0.770
# ar.L2          0.0597      0.037      1.593      0.111      -0.014       0.133
# ar.L3          0.0084      0.043      0.196      0.845      -0.075       0.092
# ar.L4          0.0534      0.045      1.193      0.233      -0.034       0.141
# ar.L5          0.0076      0.044      0.174      0.862      -0.078       0.093
# ar.L6          0.0808      0.037      2.189      0.029       0.008       0.153
# ar.S.L12       0.0259      0.034      0.758      0.448      -0.041       0.093
# ar.S.L24       0.0358      0.039      0.925      0.355      -0.040       0.112
# ar.S.L36       0.0562      0.038      1.486      0.137      -0.018       0.130
# sigma2      4.522e+04   2136.259     21.166      0.000     4.1e+04    4.94e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                24.65
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             0.14
# Prob(H) (two-sided):                  0.35   Kurtosis:                         3.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Set up the SARIMA model with values as above
p = 6
d = 0
q = 0
P = 3
D = 0
Q = 0
m = 12

model = SARIMAX(train['ActivePower'], order=(p,d,q), seasonal_order=(P,D,Q,m), dynamic=True)
model_fit = model.fit(disp=0) # disp=0 so no display
    
test_pred = model_fit.predict(start=1, end=len(test['ActivePower']))
# Out:
# C:\Users\ishan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ishan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# make sure they have the same index (otherwise pred index gets set to 1970-01-01)
test_pred.index = test.index

# %%
df_final = pd.DataFrame(data={'Predictions':test_pred, 'Actuals':test['ActivePower'] })  
df_final.head()# use auto_arima on the training data alone - not surpisingly with only a small amount of reduced training data the results are the same
# Out:
#                            Predictions     Actuals
# 2020-03-16 00:00:00+00:00   351.611654  644.891382
# 2020-03-17 00:00:00+00:00   429.766382  857.485779
# 2020-03-18 00:00:00+00:00   431.209267  367.360814
# 2020-03-19 00:00:00+00:00   368.734426  629.455480
# 2020-03-20 00:00:00+00:00   332.053608  485.411496

# %%
df_final.shape
# Out:
# (15, 2)

# %%
print('The Coefficient of determination (R-squared) = {:.2f}'.format(r2_score(df_final['Actuals'],df_final['Predictions'])))
print('The mean absolute error (MAE)                = {:.2f}'.format(mean_absolute_error(df_final['Actuals'],df_final['Predictions'])))
print('The RMSE error (RMSE)                        = {:.2f}'.format(mean_squared_error(data['ActivePower'],predicted_power, squared=False)))
print('The Mean absolute percentage error (MAPE)    = {:.2f}'.format(mean_absolute_percentage_error(df_final['Actuals'],df_final['Predictions'])))
# Out:
# The Coefficient of determination (R-squared) = -1.89
# The mean absolute error (MAE)                = 255.12
# The RMSE error (RMSE)                        = 99.84
# The Mean absolute percentage error (MAPE)    = 0.37

# %% [markdown]
# ## A graph of predicted versus actual for last 15 days of the dataset

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %%
# 3/4 of 748 and 2/3 of 748
print('80% of 748 is {} and 2/3 of 748 is {}'.format(0.8*748, 2/3*748))
# Out:
# 80% of 748 is 598.4 and 2/3 of 748 is 498.66666666666663

# %%
# train is from 0 to 597 test is from 601 to 601 + 15 (616)

train, test = df_daily[0:600], df_daily[600:615]

# %% [markdown]
# ## Repeat the steps as above

# %%
model=pm.auto_arima(train['ActivePower'],start_p=0,d=0,start_q=0,
          max_p=15,max_q=5, 
          start_P=0,D=0, start_Q=0, 
          max_P=8, max_Q=8, 
          m=12, seasonal=True, stationary=True,
          error_action='warn',trace=True,
          supress_warnings=True,stepwise=True,
          random_state=20,n_fits=100)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=9119.597, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=8206.545, Time=0.32 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=8586.396, Time=0.40 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=9838.125, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=8210.175, Time=0.03 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=8206.564, Time=1.11 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=8205.247, Time=0.84 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=8207.318, Time=0.18 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=8208.511, Time=0.93 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=8208.644, Time=1.18 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=8207.810, Time=0.49 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=3.46 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=8199.717, Time=0.60 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=8198.372, Time=0.23 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=8199.490, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=8199.459, Time=0.54 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=8197.966, Time=0.54 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=8198.755, Time=1.58 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=8200.659, Time=1.36 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=8195.283, Time=0.72 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=8196.221, Time=0.19 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=8196.370, Time=1.92 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=8197.071, Time=0.83 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=8195.577, Time=0.28 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : AIC=8198.261, Time=1.77 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=8189.833, Time=0.92 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=8189.614, Time=0.24 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=8189.957, Time=0.43 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=8191.748, Time=0.95 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=8188.920, Time=0.18 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=8189.037, Time=1.35 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=8189.144, Time=0.40 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=8190.969, Time=1.31 sec
#  ARIMA(6,0,0)(0,0,0)[12] intercept   : AIC=8186.727, Time=0.25 sec
#  ARIMA(6,0,0)(1,0,0)[12] intercept   : AIC=8187.448, Time=1.77 sec
#  ARIMA(6,0,0)(0,0,1)[12] intercept   : AIC=8187.530, Time=0.53 sec
#  ARIMA(6,0,0)(1,0,1)[12] intercept   : AIC=8189.364, Time=1.25 sec
#  ARIMA(7,0,0)(0,0,0)[12] intercept   : AIC=8188.378, Time=0.34 sec
#  ARIMA(6,0,1)(0,0,0)[12] intercept   : AIC=8188.640, Time=0.50 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=8190.368, Time=0.43 sec
#  ARIMA(7,0,1)(0,0,0)[12] intercept   : AIC=8190.288, Time=0.56 sec
#  ARIMA(6,0,0)(0,0,0)[12]             : AIC=8193.518, Time=0.20 sec
#
# Best model:  ARIMA(6,0,0)(0,0,0)[12] intercept
# Total fit time: 31.905 seconds

# %%
# Same values as original set up
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  600
# Model:               SARIMAX(6, 0, 0)   Log Likelihood               -4085.364
# Date:                Sat, 08 Jul 2023   AIC                           8186.727
# Time:                        19:07:46   BIC                           8221.903
# Sample:                             0   HQIC                          8200.421
#                                 - 600
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     49.7934     21.651      2.300      0.021       7.358      92.229
# ar.L1          0.7171      0.036     19.912      0.000       0.647       0.788
# ar.L2          0.0586      0.041      1.417      0.157      -0.022       0.140
# ar.L3          0.0004      0.047      0.008      0.994      -0.092       0.093
# ar.L4          0.0647      0.050      1.294      0.196      -0.033       0.163
# ar.L5          0.0063      0.050      0.127      0.899      -0.091       0.104
# ar.L6          0.0829      0.041      2.001      0.045       0.002       0.164
# sigma2      4.832e+04   2513.337     19.224      0.000    4.34e+04    5.32e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                19.40
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.16   Skew:                             0.13
# Prob(H) (two-sided):                  0.29   Kurtosis:                         3.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Set up the SARIMA model with values as above
p = 6
d = 0
q = 0
P = 0
D = 0
Q = 0
m = 12

model = SARIMAX(train['ActivePower'], order=(p,d,q), seasonal_order=(P,D,Q,m))
model_fit = model.fit(disp=0) # disp=0 so no display
    
test_pred = model_fit.predict(start=1, end=len(test['ActivePower']))
# Out:
# C:\Users\ishan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ishan\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# make sure they have the same index (otherwise pred index gets set to 1970-01-01)
test_pred.index = test.index

# %%
df_final = pd.DataFrame(data={'Predictions':test_pred, 'Actuals':test['ActivePower'] })  
df_final.head()
# Out:
#                            Predictions     Actuals
# 2019-11-04 00:00:00+00:00   351.959144   97.225429
# 2019-11-05 00:00:00+00:00   430.565902   66.762473
# 2019-11-06 00:00:00+00:00   431.752278  163.937559
# 2019-11-07 00:00:00+00:00   367.693235  160.739724
# 2019-11-08 00:00:00+00:00   331.693863  121.103679

# %%
print('The Coefficient of determination (R-squared) = {:.2f}'.format(r2_score(df_final['Actuals'],df_final['Predictions'])))
print('The mean absolute error (MAE)                = {:.2f}'.format(mean_absolute_error(df_final['Actuals'],df_final['Predictions'])))
print('The RMSE error (RMSE)                        = {:.2f}'.format(mean_squared_error(df_final['Actuals'],df_final['Predictions'],squared=False)))
print('The Mean absolute percentage error (MAPE)    = {:.2f}'.format(mean_absolute_percentage_error(df_final['Actuals'],df_final['Predictions'])))
# Out:
# The Coefficient of determination (R-squared) = -3.26
# The mean absolute error (MAE)                = 195.07
# The RMSE error (RMSE)                        = 227.74
# The Mean absolute percentage error (MAPE)    = 1.26

# %% [markdown]
# ## A graph using 80% of the dataset for training to predict the 15 days after that.

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ## Results for 2 previous steps (733 days and 600 days) weren't great so I didn't end up bothering with the 2/3 of the training data to run through.

# %% [markdown]
# # Now to investigate some other models to see if a better prediction can be made.
#
# ## Using XGBoost I will set the input values (x) as WindSpeed values and output (y) as the ActivePower values for training an XGBoost model
# ## Training data (X_train and y_train) is all the data without the last 15 days , then the testing data (X_test and y_test) values become the last 15 days as above.
#
# ## The XGBoost algorithm performs much better and the predictions are much closer to the actuals as can be seen from the graph below. An R2 score 0f 0.91 and lower MAE and RMSE

# %%
# train is from 0 to 733 test is from 733 to 748 - 

X_train, X_test, y_train,y_test = df_daily['WindSpeed'][0:733], df_daily['WindSpeed'][733:748], df_daily['ActivePower'][0:733],  df_daily['ActivePower'][733:748]
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (733, 15, 733, 15)

# %%
# define an XGBoost regressor
model = xgb.XGBRegressor(n_estimators=1000)

# %%
# Fit the model to the training data 
model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)],
          early_stopping_rounds=50, #stop if 50 consequent rounds without decrease of error
          verbose=False)
# Out:
# C:\Users\ishan\anaconda3\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# Make the predictions
pred = model.predict(X_test)

# %%
df_final = pd.DataFrame(data={'Actuals':y_test, 'Predictions':pred })

# %%
print('The Coefficient of determination (R-squared) = {:.3f}'.format(r2_score(df_final['Actuals'],df_final['Predictions'])))
print('The mean absolute error (MAE)                = {:.2f}'.format(mean_absolute_error(df_final['Actuals'],df_final['Predictions'])))
print('The RMSE error (RMSE)                        = {:.2f}'.format(mean_squared_error(df_final['Actuals'],df_final['Predictions'],squared=False)))
print('The Mean absolute percentage error (MAPE)    = {:.3f}'.format(mean_absolute_percentage_error(df_final['Actuals'],df_final['Predictions'])))
# Out:
# The Coefficient of determination (R-squared) = 0.909
# The mean absolute error (MAE)                = 41.45
# The RMSE error (RMSE)                        = 51.93
# The Mean absolute percentage error (MAPE)    = 0.062

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ## Next I try a RandomForest regressor - repeat similar steps to above

# %%
# train is from 0 to 733 test is from 733 to 748 - 

X_train, X_test, y_train,y_test = df_daily[['WindSpeed']][0:733], df_daily[['WindSpeed']][733:748], df_daily[['ActivePower']][0:733],  df_daily[['ActivePower']][733:748]
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((733, 1), (15, 1), (733, 1), (15, 1))

# %%
# define the model parameters
model = RandomForestRegressor(n_estimators=1000) #, max_depth=2, max_features = 'sqrt',verbose = 1, bootstrap = False)

# %%
# Fit the model to the training data 
model.fit(X_train, y_train)
# Out:
# C:\Users\ishan\AppData\Local\Temp\ipykernel_61980\263874903.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# RandomForestRegressor(n_estimators=1000)

# %%
# Make the predictions
pred = model.predict(X_test)

# %%
df_final = pd.DataFrame(data={'Actuals':y_test['ActivePower'], 'Predictions':pred}, index=y_test.index)

# %%
print('The Coefficient of determination (R-squared) = {:.3f}'.format(r2_score(df_final['Actuals'],df_final['Predictions'])))
print('The mean absolute error (MAE)                = {:.2f}'.format(mean_absolute_error(df_final['Actuals'],df_final['Predictions'])))
print('The RMSE error (RMSE)                        = {:.2f}'.format(mean_squared_error(df_final['Actuals'],df_final['Predictions'],squared=False)))
print('The Mean absolute percentage error (MAPE)    = {:.3f}'.format(mean_absolute_percentage_error(df_final['Actuals'],df_final['Predictions'])))
# Out:
# The Coefficient of determination (R-squared) = 0.912
# The mean absolute error (MAE)                = 40.64
# The RMSE error (RMSE)                        = 51.08
# The Mean absolute percentage error (MAPE)    = 0.064

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# An LSTM is the last thing that I will do. Using the same training data as above the first thing to do is to convert it into the right format to feed into the LSTM. In this case the values for X_train and y_train are somewhat different - now we use the values from multiple previous rows to predict the next ActivePower value. In this case I will use 35 rows of previous data as a guide to forecasting the next 15 values (this makes sense given there is a monthly pattern)
#
# So the first 698 values are reserved for training and the last 50 for testing.
#
# After lots of playing around with changing the number of neurons and batch size I simply could not acheive good results using an LSTM

# %%
# train is from 0 to 698 test is from 698 to 748
  
train, test = df_daily['ActivePower'][0:698], df_daily['ActivePower'][698:748]
train.shape,test.shape
# Out:
# ((698,), (50,))

# %%
scaler = MinMaxScaler(feature_range=(0,1))
#scaler.fit(train)
train = scaler.fit_transform(train.values.reshape(-1,1))
test = scaler.transform(test.values.reshape(-1,1))

# %%
# define a function to create X and y  sets from the  training dataset
# still need to reshape input to be 3D [samples, timesteps, features]

def split_X_y(df, n_steps_in, n_steps_out):
    X, y = [],[]
    for i in range(len(df)):
        # find the end of this pattern
        end_index = i + n_steps_in
        out_end_index = end_index + n_steps_out
        # check if we are beyond the sequence
        if out_end_index > len(df):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = df[i:end_index], df[end_index:out_end_index]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 35, 15
# split into samples
train_X, train_y = split_X_y(train, n_steps_in, n_steps_out)
test_X, test_y   = split_X_y(test, n_steps_in, n_steps_out)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((649, 35, 1), (649, 15, 1), (1, 35, 1), (1, 15, 1))

# %%
# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
train_X_res = train_X.reshape((train_X.shape[0], train_X.shape[1], n_features))
train_y_res = train_y.reshape((train_y.shape[0], train_y.shape[1], n_features))

test_X_res  = test_X.reshape((test_X.shape[0], test_X.shape[1], n_features))
test_y_res  = test_y.reshape((test_y.shape[0], test_y.shape[1], n_features))
train_X_res.shape, train_y_res.shape, test_X_res.shape, test_y_res.shape
# Out:
# ((649, 35, 1), (649, 15, 1), (1, 35, 1), (1, 15, 1))

# %%
# define model
model = Sequential()
# 1st layer 128 neurons, return sequence is true to stack the next layer and dropout set at 20% and BatchNormalization
model.add(LSTM(128, activation='relu', return_sequences=True, input_shape=(n_steps_in, n_features)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# 2nd layer 64 neurons, return sequence is now false so it returns and dropout set at 20%
model.add(LSTM(64, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# final layer is the number of days of forecasts needed
model.add(Dense(n_steps_out))

# %%
4# Compile and run the model amd plot the loss function, num epochs set at 200 but early stopping means should not reach that
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()]) 
#  early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
# fit network 
history = model.fit(train_X_res, train_y_res, epochs=200,verbose=0, batch_size=64, validation_data=(test_X_res,  test_y_res), shuffle=False, callbacks=[es]) 
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 181: early stopping

# %%
# demonstrate prediction
prediction = model.predict(test_X_res, verbose=0)
#print(scaler.inverse_transform(prediction))
pred = scaler.inverse_transform(prediction)

# %%
pred[0][0:15]
# Out:
# array([647.6429 , 635.0601 , 627.6182 , 628.0227 , 650.3532 , 667.8624 ,
#        649.1792 , 680.9913 , 651.85486, 665.7978 , 674.0771 , 680.499  ,
#        710.6882 , 720.9457 , 669.5824 ], dtype=float32)

# %%
df_final = pd.DataFrame(data={'Actuals':df_daily['ActivePower'][733:748], 'Predictions':pred[0][0:15]}, index = df_daily[733:748].index)

# %%
df_final
# Out:
#                               Actuals  Predictions
# 2020-03-16 00:00:00+00:00  644.891382   647.642883
# 2020-03-17 00:00:00+00:00  857.485779   635.060120
# 2020-03-18 00:00:00+00:00  367.360814   627.618225
# 2020-03-19 00:00:00+00:00  629.455480   628.022705
# 2020-03-20 00:00:00+00:00  485.411496   650.353210
# 2020-03-21 00:00:00+00:00  432.529893   667.862427
# 2020-03-22 00:00:00+00:00  481.172384   649.179199
# 2020-03-23 00:00:00+00:00  552.187880   680.991272
# 2020-03-24 00:00:00+00:00  425.815287   651.854858
# 2020-03-25 00:00:00+00:00  754.076163   665.797791
# 2020-03-26 00:00:00+00:00  732.042233   674.077087
# 2020-03-27 00:00:00+00:00  728.896074   680.499023
# 2020-03-28 00:00:00+00:00  874.011580   710.688171
# 2020-03-29 00:00:00+00:00  840.439852   720.945679
# 2020-03-30 00:00:00+00:00  873.498776   669.582397

# %%
print('The Coefficient of determination (R-squared) = {:.2f}'.format(r2_score(df_final['Actuals'],df_final['Predictions'])))
print('The mean absolute error (MAE)                = {:.2f}'.format(mean_absolute_error(df_final['Actuals'],df_final['Predictions'])))
print('The RMSE error (RMSE)                        = {:.2f}'.format(mean_squared_error(df_final['Actuals'],df_final['Predictions'],squared=False)))
print('The Mean absolute percentage error (MAPE)    = {:.2f}'.format(mean_absolute_percentage_error(df_final['Actuals'],df_final['Predictions'])))
# Out:
# The Coefficient of determination (R-squared) = 0.12
# The mean absolute error (MAE)                = 139.42
# The RMSE error (RMSE)                        = 161.61
# The Mean absolute percentage error (MAPE)    = 0.25

# %%
# plot
plt.plot(df_final['Predictions'],label='Prediction')
plt.plot(df_final['Actuals'], color='red',label='Actual')

plt.ylabel('Active Power')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Results and discussion
#
#  Originally when I started this work I thought that a SARIMA model would work best given the state of the data - namely that there was seasonal component to it. However, the proved not to be the case. Also I thought using an LSTM neural network would provide good results but this was also not true. In the end it was the simplest methods that provided the best results - that is both the RandomForest and XGBoost regressors - with RandomForest being slightly better (the R squared better but MAPE slightly worse but I had to go to 3 figures to differentiate).
#
#  Overall the general statement that can be made is that either of XGBoost or Randomforest regressor could predict the next 15 days of power output to roughly 94% accurracy (or a mean average percentage error of 6%) and that roughly 91% of the variance in the data (R squared) is explained by either method. And both of these methods achieved a result much faster.
#
#  Note without a random_state set for each method the results generated in the submitted notebook will differ from the figures given here.
#
# |Method|R squared|RMSE|MAE|MAPE|
# |---|---|---|---|---|
# |SARIMAX (733 days training)|-1.89|225.06|99.84|0.37|
# |SARIMAX (600 days training)|-3.26|195.07|227.74|1.26|
# |Extreme gradient boost (XGBoost)|0.909|42.45|51.93|0.062|
# |RandomForestRegressor| 0.911|40.64|51.08|0.064|
# |LSTM|0.12|139.42|161.61|0.25|
